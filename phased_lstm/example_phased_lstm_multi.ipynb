# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from sklearn.preprocessing import MinMaxScaler

from keras.callbacks import Callback, ModelCheckpoint
from keras.layers import Dense, LSTM, Activation, Dropout
from keras.models import Sequential, load_model
from keras.utils import np_utils
import keras.backend as K

# Keras implementation of Phased LSTM [https://arxiv.org/abs/1610.09513], from NIPS 2016.
# To install run: `pip install phased_lstm_keras`
from phased_lstm_keras.PhasedLSTM import PhasedLSTM as PLSTM
# Out:
# Using TensorFlow backend.

# %%
# 数据集读取及预处理
def read_dataset(filepath):
    print(filepath)
    
    #读取原始数据集，保留原始数据文件，日期格式转换，设置日期为索引列
    data_raw = pd.read_csv(filepath_or_buffer=filepath, usecols=['DATE','TEMP','PRICE','SALES','COUPON','HOLIDAY'], 
                           parse_dates={'Timeline':['DATE']}, index_col='Timeline')

    print('shape before dropna:', data_raw.shape)

    #去除qty值为NaN的行，*另可考虑填充均值
    data_raw = data_raw.dropna()
    #pandas 0.20版本，sort() => sort_index()，按日期排序
    data_raw = data_raw.sort_index()

    print('shape after dropna:', data_raw.shape)    
    print(data_raw.describe())
    
    return data_raw


# 建立训练和测试数据集
def create_dataset(dataset, seq_len=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-seq_len-1):
        dataX.append(dataset[i: i + seq_len])
        dataY.append(dataset[:,2][i + seq_len])
            
    return np.array(dataX).astype('float64'), np.array(dataY).astype('float64')

# %%
# 特征缩放 - 调节比例
def feature_rescaling(mat,col):
    data = mat
    data[:,col]=(data[:,col]-data[:,col].min())/(data[:,col].max()-data[:,col].min()) 
    return data

def feature_inverse_rescaling(mat,col,min,max):
    data = mat
    data[:,col]=data[:,col]*(max-min)+min
    return data

# 特征缩放 - 标准化
def feature_standardization(mat,col):
    data = mat
    data[:,col]=(data[:,col]-data[:,col].mean())/data[:,col].std()
    return data
    
def feature_inverse_standardization(mat,col,mean,std):
    data = mat
    data[:,col]=data[:,col]*std+mean
    return data

# %%
# 用于在训练过程中记录accuracy和loss的变化值
class MapeHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get(mape))


class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        

def mape(y_true, y_pred):
    # 此处如果/y_true, 在训练过程中，y_true会变成0，导致inf，因为数据集中最小值归一化后变成了0
    return abs(y_true-y_pred)

# %%
# 建立Phased LSTM模型
def bulid_model_plstm(layers):
    model = Sequential()
    
    model.add(PLSTM(
        input_shape=(layers[1], layers[0]),
        units=layers[1],
        return_sequences=True))
    model.add(Dropout(0.2))

    model.add(PLSTM(
        layers[2],
        return_sequences=False))
    model.add(Dropout(0.2))

    model.add(Dense(units=layers[3], activation='linear'))

    model.compile(optimizer='rmsprop', loss='mean_squared_error', metrics=[mape])
    model.summary()

    return model


# 建立标准LSTM模型
def bulid_model_lstm(layers):
    model = Sequential()
    
    model.add(LSTM(
        input_shape=(layers[1], layers[0]),
        units=layers[1],
        return_sequences=True))
    model.add(Dropout(0.2))

    model.add(LSTM(
        layers[2],
        return_sequences=False))
    model.add(Dropout(0.2))

    model.add(Dense(units=layers[3], activation='linear'))

    model.compile(optimizer='rmsprop', loss='mean_squared_error', metrics=[mape])
    model.summary()

    return model

# %%
if __name__ == "__main__":

    # 读取原始数据集，数据可视化
    train_raw = read_dataset('train_data_mv_multi.csv')
    
    print(train_raw[:5])
    
    plt.figure(figsize=(20,5))
    plt.plot(train_raw['SALES'])
    plt.show()
    
    fig,ax = plt.subplots(2,2,figsize=[20,5])
    ax[0,0].plot(train_raw['TEMP'])
    ax[0,1].plot(train_raw['PRICE'])
    
    ax[1,0].plot(train_raw['COUPON'])
    ax[1,1].plot(train_raw['HOLIDAY'])
   
    plt.show()
# Out:
# train_data_mv_multi.csv
# shape before dropna: (2445, 5)
# shape after dropna: (2358, 5)
#               TEMP        PRICE        SALES       COUPON      HOLIDAY
# count  2358.000000  2358.000000  2358.000000  2358.000000  2358.000000
# mean     58.249724     5.954198   186.195081     0.025021     0.019508
# std       7.086737     0.161023    75.433074     0.156223     0.138332
# min      35.100000     4.980164    52.000000     0.000000     0.000000
# 25%      53.100000     5.990000   143.000000     0.000000     0.000000
# 50%      59.000000     5.990000   172.000000     0.000000     0.000000
# 75%      63.000000     5.990000   210.000000     0.000000     0.000000
# max      81.050000     5.996452   901.000000     1.000000     1.000000
#             TEMP  PRICE  SALES  COUPON  HOLIDAY
# Timeline
# 2010-09-01  75.2   5.79  222.0     0.0        0
# 2010-09-02  74.9   5.79  207.0     0.0        0
# 2010-09-03  66.0   5.79  292.0     0.0        0
# 2010-09-04  62.1   5.79  221.0     0.0        0
# 2010-09-05  64.0   5.79  214.0     0.0        0

# %%
    test_raw = read_dataset('test_data_mv_multi.csv')
    
    print(test_raw[:5])
    
    plt.figure(figsize=(20,5))
    plt.plot(test_raw['SALES'])
    plt.show()
    
    fig,ax = plt.subplots(2,2,figsize=[20,5])
    ax[0,0].plot(test_raw['TEMP'])
    ax[0,1].plot(test_raw['PRICE'])
    
    ax[1,0].plot(test_raw['COUPON'])
    ax[1,1].plot(test_raw['HOLIDAY'])
   
    plt.show()
# Out:
# test_data_mv_multi.csv
# shape before dropna: (120, 5)
# shape after dropna: (119, 5)
#              TEMP       PRICE       SALES      COUPON  HOLIDAY
# count  119.000000  119.000000  119.000000  119.000000    119.0
# mean    63.259664    5.855575  317.411765    0.134454      0.0
# std      5.977547    0.342593  108.731859    0.342582      0.0
# min     50.000000    4.990000  168.000000    0.000000      0.0
# 25%     59.000000    5.990000  253.000000    0.000000      0.0
# 50%     62.550000    5.990000  281.000000    0.000000      0.0
# 75%     66.450000    5.990000  338.000000    0.000000      0.0
# max     82.950000    5.993484  718.000000    1.000000      0.0
#              TEMP  PRICE  SALES  COUPON  HOLIDAY
# Timeline
# 2017-04-01  62.95   4.99  590.0     1.0        0
# 2017-04-02  59.00   4.99  664.0     1.0        0
# 2017-04-03  56.90   4.99  617.0     1.0        0
# 2017-04-04  60.55   4.99  486.0     1.0        0
# 2017-04-05  62.55   4.99  516.0     1.0        0

# %%
    # 数据归一化处理
    
    #scaler = MinMaxScaler(feature_range=(0, 1))
    #train = scaler.fit_transform(train_raw)
    #test = scaler.fit_transform(test_raw)    
    
    train = np.mat(train_raw)
    test = np.mat(test_raw)
    
    # 记录sales的均值和标准差，用于预测后的反向缩放
    train_min = train[:,2].min()
    train_max = train[:,2].max()
    test_min = test[:,2].min()
    test_max = test[:,2].max()
        
    train = feature_rescaling(train,2)
    test = feature_rescaling(test,2)
    
    train = feature_rescaling(train,0)
    test = feature_rescaling(test,0)
    
    train[:,1] = train[:,1]/6
    test[:,1] = test[:,1]/6
    
    
    print(train.shape, 'min:', train_min ,'max:', train_max)
    print(train[:5])
    
    print(test.shape, 'min:', test_min ,'max:', test_max)
    print(test[:5])
# Out:
# (2358, 5) min: 52.0 max: 901.0
# [[ 0.8726877   0.965       0.20023557  0.          0.        ]
#  [ 0.86615887  0.965       0.18256773  0.          0.        ]
#  [ 0.67247008  0.965       0.28268551  0.          0.        ]
#  [ 0.58759521  0.965       0.19905771  0.          0.        ]
#  [ 0.6289445   0.965       0.19081272  0.          0.        ]]
# (119, 5) min: 168.0 max: 718.0
# [[ 0.39301973  0.83166667  0.76727273  1.          0.        ]
#  [ 0.27314112  0.83166667  0.90181818  1.          0.        ]
#  [ 0.20940819  0.83166667  0.81636364  1.          0.        ]
#  [ 0.32018209  0.83166667  0.57818182  1.          0.        ]
#  [ 0.38088012  0.83166667  0.63272727  1.          0.        ]]

# %%
    seq_len = 30
    
    train = np.array(train).astype(float)
    
    trainX, trainY = create_dataset(train, seq_len)
    
    trainX = np.reshape(trainX, (trainX.shape[0], seq_len, trainX.shape[2]))
    trainY = np.reshape(trainY, (trainY.shape[0], 1))
    
    print('trainset after resharp')
    print('X shape', trainX.shape,'\n', trainX[:1])
    print('Y shape', trainY.shape,'\n', trainY[:1])
# Out:
# trainset after resharp
# X shape (2327, 30, 5)
#  [[[ 0.8726877   0.965       0.20023557  0.          0.        ]
#   [ 0.86615887  0.965       0.18256773  0.          0.        ]
#   [ 0.67247008  0.965       0.28268551  0.          0.        ]
#   [ 0.58759521  0.965       0.19905771  0.          0.        ]
#   [ 0.6289445   0.965       0.19081272  0.          0.        ]
#   [ 0.6289445   0.965       0.34393404  0.          0.        ]
#   [ 0.60718172  0.965       0.29681979  0.          0.        ]
#   [ 0.55168662  0.965       0.30742049  0.          0.        ]
#   [ 0.71599565  0.965       0.25795053  0.          0.        ]
#   [ 0.71599565  0.965       0.28150766  0.          0.        ]
#   [ 0.58759521  0.965       0.38633687  0.          0.        ]
#   [ 0.48857454  0.965       0.30388693  0.          0.        ]
#   [ 0.52013058  0.965       0.22143698  0.          0.        ]
#   [ 0.53210011  0.965       0.21201413  0.          0.        ]
#   [ 0.67247008  0.965       0.25912839  0.          0.        ]
#   [ 0.69205658  0.965       0.2532391   0.          0.        ]
#   [ 0.64853101  0.965       0.27679623  0.          0.        ]
#   [ 0.60718172  0.965       0.27679623  0.          0.        ]
#   [ 0.59847661  0.965       0.20848057  0.          0.        ]
#   [ 0.56365615  0.965       0.07420495  0.          0.        ]
#   [ 0.54406964  0.965       0.08244994  0.          0.        ]
#   [ 0.57562568  0.965       0.05771496  0.          0.        ]
#   [ 0.77149075  0.965       0.06713781  0.          0.        ]
#   [ 0.82480958  0.965       0.06831567  0.          0.        ]
#   [ 0.78890098  0.965       0.11896349  0.          0.        ]
#   [ 0.89989119  0.965       0.10365135  0.          0.        ]
#   [ 0.92383025  0.965       0.0753828   0.          0.        ]
#   [ 0.84439608  0.965       0.09069494  0.          0.        ]
#   [ 0.64853101  0.965       0.08716137  0.          0.        ]
#   [ 0.59847661  0.965       0.12249706  0.          0.        ]]]
# Y shape (2327, 1)
#  [[ 0.12603062]]

# %%
    test = np.array(test).astype(float)
    
    test_addon = np.concatenate((train[len(train)-seq_len:len(train)], test))
    
    print(test_addon.shape)
    
    testX, testY = create_dataset(test_addon, seq_len)
    
    testX = np.reshape(testX, (testX.shape[0], seq_len, testX.shape[2]))
    testY = np.reshape(testY, (testY.shape[0], 1))
    
    print('testset after resharp')
    print('X shape', testX.shape,'\n', testX[:1])
    print('Y shape', testY.shape,'\n', testY[:1])
# Out:
# (149, 5)
# testset after resharp
# X shape (118, 30, 5)
#  [[[ 0.40152339  0.99833333  0.26030624  0.          0.        ]
#   [ 0.35799782  0.99833333  0.28504122  0.          0.        ]
#   [ 0.39173014  0.99833333  0.38987044  0.          0.        ]
#   [ 0.28073993  0.99833333  0.52885748  0.          0.        ]
#   [ 0.30250272  0.99833333  0.39693757  0.          0.        ]
#   [ 0.36779108  0.99833333  0.2991755   0.          0.        ]
#   [ 0.45266594  0.99833333  0.30388693  0.          0.        ]
#   [ 0.52013058  0.99833333  0.27561837  0.          0.        ]
#   [ 0.54406964  0.99833333  0.28975265  0.          0.        ]
#   [ 0.49619151  0.99833333  0.34275618  0.          0.        ]
#   [ 0.40261153  0.99833333  0.44758539  0.          0.        ]
#   [ 0.61806311  0.99833333  0.34275618  0.          0.        ]
#   [ 0.59738847  0.99833333  0.2426384   0.          0.        ]
#   [ 0.52013058  0.99833333  0.28504122  0.          0.        ]
#   [ 0.49619151  0.99833333  0.22850412  0.          0.        ]
#   [ 0.57562568  0.99833333  0.26619552  0.          0.        ]
#   [ 0.49619151  0.99833333  0.26737338  0.          0.        ]
#   [ 0.47660501  0.99833333  0.40400471  0.          0.        ]
#   [ 0.52013058  0.99833333  0.3451119   0.          0.        ]
#   [ 0.54406964  0.99833333  0.28504122  0.          0.        ]
#   [ 0.41131665  0.99833333  0.23792697  0.          0.        ]
#   [ 0.39173014  0.83129423  0.99293286  1.          0.        ]
#   [ 0.43307943  0.83141452  0.71731449  1.          0.        ]
#   [ 0.41131665  0.83147662  0.97173145  1.          0.        ]
#   [ 0.44287269  0.83148169  1.          1.          0.        ]
#   [ 0.41131665  0.83166667  0.87279152  1.          0.        ]
#   [ 0.50816104  0.83166667  0.67844523  1.          0.        ]
#   [ 0.49836779  0.83136029  0.5795053   1.          0.        ]
#   [ 0.45266594  0.83166667  0.61248528  1.          0.        ]
#   [ 0.54406964  0.83166667  0.69964664  1.          1.        ]]]
# Y shape (118, 1)
#  [[ 0.76727273]]

# %%
    batch_size = 16
    nb_epoch = 25
    is_train = True
    
    # 训练PLSTM网络    
    # 输入维度 [n, layer1 seq_len, layer2 seq_len, out]
    model_PLSTM = bulid_model_plstm([5, seq_len, seq_len*2, 1])
    
    mape_PLSTM = MapeHistory()
    loss_PLSTM = LossHistory()
        
    #acc_LSTM = AccHistory()
    loss_PLSTM = LossHistory()
    
    checkpoint_fixed_name = ModelCheckpoint("model_plstm_multi_best_e{epoch:02d}-{val_loss:.4f}.hd5", 
                                            monitor='val_loss', verbose=1, save_best_only=True, 
                                            save_weights_only=False, mode='auto', period=1)
    
    if is_train:
        model_PLSTM.fit(trainX, trainY, epochs=nb_epoch, batch_size=batch_size,
                       validation_split=0.05, callbacks=[loss_PLSTM, mape_PLSTM, checkpoint_fixed_name])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# phased_lstm_1 (PhasedLSTM)   (None, 30, 30)            4410
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30)            0
# _________________________________________________________________
# phased_lstm_2 (PhasedLSTM)   (None, 60)                22020
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 61
# =================================================================
# Total params: 26,491
# Trainable params: 26,491
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2210 samples, validate on 117 samples
# Epoch 1/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0068 - mape: 0.0547Epoch 00000: val_loss improved from inf to 0.05429, saving model to model_plstm_multi_best_e00-0.0543.hd5
# 2210/2210 [==============================] - 27s - loss: 0.0068 - mape: 0.0546 - val_loss: 0.0543 - val_mape: 0.1757
# Epoch 2/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0053 - mape: 0.0485Epoch 00001: val_loss improved from 0.05429 to 0.04589, saving model to model_plstm_multi_best_e01-0.0459.hd5
# 2210/2210 [==============================] - 24s - loss: 0.0053 - mape: 0.0485 - val_loss: 0.0459 - val_mape: 0.1515
# Epoch 3/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0047 - mape: 0.0464Epoch 00002: val_loss improved from 0.04589 to 0.04086, saving model to model_plstm_multi_best_e02-0.0409.hd5
# 2210/2210 [==============================] - 24s - loss: 0.0047 - mape: 0.0464 - val_loss: 0.0409 - val_mape: 0.1381
# Epoch 4/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0044 - mape: 0.0452Epoch 00003: val_loss did not improve
# 2210/2210 [==============================] - 24s - loss: 0.0044 - mape: 0.0452 - val_loss: 0.0432 - val_mape: 0.1511
# Epoch 5/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0039 - mape: 0.0428Epoch 00004: val_loss improved from 0.04086 to 0.02132, saving model to model_plstm_multi_best_e04-0.0213.hd5
# 2210/2210 [==============================] - 24s - loss: 0.0039 - mape: 0.0428 - val_loss: 0.0213 - val_mape: 0.0762
# Epoch 6/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0035 - mape: 0.0405Epoch 00005: val_loss did not improve
# 2210/2210 [==============================] - 24s - loss: 0.0035 - mape: 0.0406 - val_loss: 0.0248 - val_mape: 0.0977
# Epoch 7/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0033 - mape: 0.0395Epoch 00006: val_loss did not improve
# 2210/2210 [==============================] - 24s - loss: 0.0033 - mape: 0.0395 - val_loss: 0.0279 - val_mape: 0.1155
# Epoch 8/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0030 - mape: 0.0381Epoch 00007: val_loss improved from 0.02132 to 0.02013, saving model to model_plstm_multi_best_e07-0.0201.hd5
# 2210/2210 [==============================] - 24s - loss: 0.0030 - mape: 0.0380 - val_loss: 0.0201 - val_mape: 0.0878
# Epoch 9/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0029 - mape: 0.0371Epoch 00008: val_loss improved from 0.02013 to 0.01806, saving model to model_plstm_multi_best_e08-0.0181.hd5
# 2210/2210 [==============================] - 24s - loss: 0.0029 - mape: 0.0370 - val_loss: 0.0181 - val_mape: 0.0794
# Epoch 10/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0027 - mape: 0.0359Epoch 00009: val_loss improved from 0.01806 to 0.01592, saving model to model_plstm_multi_best_e09-0.0159.hd5
# 2210/2210 [==============================] - 24s - loss: 0.0027 - mape: 0.0359 - val_loss: 0.0159 - val_mape: 0.0715
# Epoch 11/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0026 - mape: 0.0351 ETA: 2s -Epoch 00010: val_loss improved from 0.01592 to 0.01129, saving model to model_plstm_multi_best_e10-0.0113.hd5
# 2210/2210 [==============================] - 24s - loss: 0.0026 - mape: 0.0351 - val_loss: 0.0113 - val_mape: 0.0552
# Epoch 12/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0026 - mape: 0.0349Epoch 00011: val_loss did not improve
# 2210/2210 [==============================] - 25s - loss: 0.0026 - mape: 0.0349 - val_loss: 0.0140 - val_mape: 0.0649
# Epoch 13/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0024 - mape: 0.0336Epoch 00012: val_loss improved from 0.01129 to 0.01126, saving model to model_plstm_multi_best_e12-0.0113.hd5
# 2210/2210 [==============================] - 24s - loss: 0.0024 - mape: 0.0337 - val_loss: 0.0113 - val_mape: 0.0579
# Epoch 14/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0023 - mape: 0.0334Epoch 00013: val_loss improved from 0.01126 to 0.01112, saving model to model_plstm_multi_best_e13-0.0111.hd5
# 2210/2210 [==============================] - 26s - loss: 0.0023 - mape: 0.0333 - val_loss: 0.0111 - val_mape: 0.0579
# Epoch 15/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0022 - mape: 0.0325Epoch 00014: val_loss did not improve
# 2210/2210 [==============================] - 25s - loss: 0.0022 - mape: 0.0325 - val_loss: 0.0114 - val_mape: 0.0573
# Epoch 16/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0023 - mape: 0.0326Epoch 00015: val_loss improved from 0.01112 to 0.00985, saving model to model_plstm_multi_best_e15-0.0098.hd5
# 2210/2210 [==============================] - 25s - loss: 0.0023 - mape: 0.0325 - val_loss: 0.0098 - val_mape: 0.0608
# Epoch 17/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0022 - mape: 0.0319Epoch 00016: val_loss improved from 0.00985 to 0.00955, saving model to model_plstm_multi_best_e16-0.0096.hd5
# 2210/2210 [==============================] - 25s - loss: 0.0022 - mape: 0.0319 - val_loss: 0.0096 - val_mape: 0.0536
# Epoch 18/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0022 - mape: 0.0317Epoch 00017: val_loss did not improve
# 2210/2210 [==============================] - 25s - loss: 0.0022 - mape: 0.0317 - val_loss: 0.0107 - val_mape: 0.0568
# Epoch 19/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0022 - mape: 0.0323Epoch 00018: val_loss did not improve
# 2210/2210 [==============================] - 26s - loss: 0.0022 - mape: 0.0323 - val_loss: 0.0096 - val_mape: 0.0536
# Epoch 20/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0021 - mape: 0.0312Epoch 00019: val_loss did not improve
# 2210/2210 [==============================] - 24s - loss: 0.0021 - mape: 0.0312 - val_loss: 0.0102 - val_mape: 0.0546
# Epoch 21/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0021 - mape: 0.0314Epoch 00020: val_loss did not improve
# 2210/2210 [==============================] - 25s - loss: 0.0021 - mape: 0.0314 - val_loss: 0.0112 - val_mape: 0.0561
# Epoch 22/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0020 - mape: 0.0310Epoch 00021: val_loss improved from 0.00955 to 0.00953, saving model to model_plstm_multi_best_e21-0.0095.hd5
# 2210/2210 [==============================] - 25s - loss: 0.0020 - mape: 0.0310 - val_loss: 0.0095 - val_mape: 0.0529
# Epoch 23/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0021 - mape: 0.0306Epoch 00022: val_loss did not improve
# 2210/2210 [==============================] - 25s - loss: 0.0021 - mape: 0.0306 - val_loss: 0.0109 - val_mape: 0.0582
# Epoch 24/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0019 - mape: 0.0305Epoch 00023: val_loss improved from 0.00953 to 0.00888, saving model to model_plstm_multi_best_e23-0.0089.hd5
# 2210/2210 [==============================] - 26s - loss: 0.0019 - mape: 0.0305 - val_loss: 0.0089 - val_mape: 0.0519
# Epoch 25/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0020 - mape: 0.0308Epoch 00024: val_loss did not improve
# 2210/2210 [==============================] - 25s - loss: 0.0020 - mape: 0.0308 - val_loss: 0.0096 - val_mape: 0.0545

# %%
    # 训练LSTM网络
    # 输入维度 [n, layer1 seq_len, layer2 seq_len, out]
    model_LSTM = bulid_model_lstm([5, seq_len, seq_len*2, 1])
    
    mape_LSTM = MapeHistory()
    loss_LSTM = LossHistory()
    
    checkpoint_fixed_name = ModelCheckpoint("model_lstm_multi_best_e{epoch:02d}-{val_loss:.4f}.hd5", 
                                            monitor='val_loss', verbose=1, save_best_only=True, 
                                            save_weights_only=False, mode='auto', period=1)
    
    if is_train:
        model_LSTM.fit(trainX, trainY, epochs=nb_epoch, batch_size=batch_size,
                   validation_split=0.05, callbacks=[loss_LSTM, mape_LSTM, checkpoint_fixed_name])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 30, 30)            4320
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 30, 30)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 60)                21840
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 60)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 61
# =================================================================
# Total params: 26,221
# Trainable params: 26,221
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2210 samples, validate on 117 samples
# Epoch 1/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0045 - mape: 0.0488Epoch 00000: val_loss improved from inf to 0.03067, saving model to model_lstm_multi_best_e00-0.0307.hd5
# 2210/2210 [==============================] - 16s - loss: 0.0045 - mape: 0.0488 - val_loss: 0.0307 - val_mape: 0.1248
# Epoch 2/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0033 - mape: 0.0415Epoch 00001: val_loss improved from 0.03067 to 0.01287, saving model to model_lstm_multi_best_e01-0.0129.hd5
# 2210/2210 [==============================] - 15s - loss: 0.0033 - mape: 0.0415 - val_loss: 0.0129 - val_mape: 0.0649
# Epoch 3/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0033 - mape: 0.0409Epoch 00002: val_loss did not improve
# 2210/2210 [==============================] - 15s - loss: 0.0033 - mape: 0.0409 - val_loss: 0.0186 - val_mape: 0.0824
# Epoch 4/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0030 - mape: 0.0387Epoch 00003: val_loss did not improve
# 2210/2210 [==============================] - 15s - loss: 0.0030 - mape: 0.0387 - val_loss: 0.0181 - val_mape: 0.0825
# Epoch 5/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0029 - mape: 0.0394Epoch 00004: val_loss did not improve
# 2210/2210 [==============================] - 15s - loss: 0.0029 - mape: 0.0394 - val_loss: 0.0192 - val_mape: 0.0910
# Epoch 6/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0028 - mape: 0.0386Epoch 00005: val_loss did not improve
# 2210/2210 [==============================] - 16s - loss: 0.0028 - mape: 0.0386 - val_loss: 0.0223 - val_mape: 0.1025
# Epoch 7/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0028 - mape: 0.0377Epoch 00006: val_loss did not improve
# 2210/2210 [==============================] - 16s - loss: 0.0028 - mape: 0.0377 - val_loss: 0.0176 - val_mape: 0.0836
# Epoch 8/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0028 - mape: 0.0381Epoch 00007: val_loss did not improve
# 2210/2210 [==============================] - 14s - loss: 0.0028 - mape: 0.0381 - val_loss: 0.0199 - val_mape: 0.0946
# Epoch 9/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0026 - mape: 0.0369Epoch 00008: val_loss improved from 0.01287 to 0.01126, saving model to model_lstm_multi_best_e08-0.0113.hd5
# 2210/2210 [==============================] - 15s - loss: 0.0026 - mape: 0.0369 - val_loss: 0.0113 - val_mape: 0.0622
# Epoch 10/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0025 - mape: 0.0365Epoch 00009: val_loss did not improve
# 2210/2210 [==============================] - 15s - loss: 0.0025 - mape: 0.0365 - val_loss: 0.0116 - val_mape: 0.0784
# Epoch 11/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0026 - mape: 0.0372Epoch 00010: val_loss improved from 0.01126 to 0.00961, saving model to model_lstm_multi_best_e10-0.0096.hd5
# 2210/2210 [==============================] - 15s - loss: 0.0026 - mape: 0.0372 - val_loss: 0.0096 - val_mape: 0.0575
# Epoch 12/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0025 - mape: 0.0361Epoch 00011: val_loss did not improve
# 2210/2210 [==============================] - 15s - loss: 0.0025 - mape: 0.0360 - val_loss: 0.0118 - val_mape: 0.0633
# Epoch 13/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0025 - mape: 0.0359Epoch 00012: val_loss did not improve
# 2210/2210 [==============================] - 15s - loss: 0.0025 - mape: 0.0359 - val_loss: 0.0149 - val_mape: 0.0793
# Epoch 14/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0023 - mape: 0.0351Epoch 00013: val_loss did not improve
# 2210/2210 [==============================] - 17s - loss: 0.0023 - mape: 0.0351 - val_loss: 0.0115 - val_mape: 0.0610
# Epoch 15/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0022 - mape: 0.0343Epoch 00014: val_loss improved from 0.00961 to 0.00872, saving model to model_lstm_multi_best_e14-0.0087.hd5
# 2210/2210 [==============================] - 15s - loss: 0.0022 - mape: 0.0343 - val_loss: 0.0087 - val_mape: 0.0534
# Epoch 16/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0022 - mape: 0.0344Epoch 00015: val_loss did not improve
# 2210/2210 [==============================] - 15s - loss: 0.0022 - mape: 0.0344 - val_loss: 0.0121 - val_mape: 0.0662
# Epoch 17/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0023 - mape: 0.0342Epoch 00016: val_loss did not improve
# 2210/2210 [==============================] - 15s - loss: 0.0023 - mape: 0.0342 - val_loss: 0.0122 - val_mape: 0.0688
# Epoch 18/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0023 - mape: 0.0336Epoch 00017: val_loss did not improve
# 2210/2210 [==============================] - 15s - loss: 0.0023 - mape: 0.0336 - val_loss: 0.0095 - val_mape: 0.0552
# Epoch 19/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0021 - mape: 0.0334Epoch 00018: val_loss did not improve
# 2210/2210 [==============================] - 15s - loss: 0.0021 - mape: 0.0334 - val_loss: 0.0112 - val_mape: 0.0640
# Epoch 20/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0021 - mape: 0.0330Epoch 00019: val_loss did not improve
# 2210/2210 [==============================] - 15s - loss: 0.0021 - mape: 0.0329 - val_loss: 0.0094 - val_mape: 0.0539
# Epoch 21/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0021 - mape: 0.0329Epoch 00020: val_loss did not improve
# 2210/2210 [==============================] - 15s - loss: 0.0021 - mape: 0.0329 - val_loss: 0.0108 - val_mape: 0.0596
# Epoch 22/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0021 - mape: 0.0324Epoch 00021: val_loss improved from 0.00872 to 0.00861, saving model to model_lstm_multi_best_e21-0.0086.hd5
# 2210/2210 [==============================] - 15s - loss: 0.0021 - mape: 0.0324 - val_loss: 0.0086 - val_mape: 0.0520
# Epoch 23/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0021 - mape: 0.0320Epoch 00022: val_loss improved from 0.00861 to 0.00778, saving model to model_lstm_multi_best_e22-0.0078.hd5
# 2210/2210 [==============================] - 15s - loss: 0.0021 - mape: 0.0320 - val_loss: 0.0078 - val_mape: 0.0532
# Epoch 24/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0019 - mape: 0.0312Epoch 00023: val_loss did not improve
# 2210/2210 [==============================] - 15s - loss: 0.0019 - mape: 0.0312 - val_loss: 0.0093 - val_mape: 0.0524
# Epoch 25/25
# 2208/2210 [============================>.] - ETA: 0s - loss: 0.0020 - mape: 0.0313Epoch 00024: val_loss did not improve
# 2210/2210 [==============================] - 15s - loss: 0.0020 - mape: 0.0313 - val_loss: 0.0143 - val_mape: 0.0758

# %%
    if is_train == False:
        model_PLSTM.load_weights('model_plstm_multi_best.hd5')
    
    # plstm预测结果
    
    trainPredict = model_PLSTM.predict(trainX)
    testPredict = model_PLSTM.predict(testX)
    
    trainPredict = feature_inverse_rescaling(trainPredict,0,train_min,train_max)
    trainY_raw = feature_inverse_rescaling(trainY,0,train_min,train_max)
    
    testPredict = feature_inverse_rescaling(testPredict,0,test_min,test_max)
    testY_raw = feature_inverse_rescaling(testY,0,test_min,test_max)
       
    print(trainY_raw.shape, trainPredict.shape)    
    trainScore = np.mean(abs((trainY_raw[0]-trainPredict[:,0])/trainY_raw[0]))
    print('Train Score: %.3f MAPE' % (trainScore))
    
    print(testY_raw.shape, testPredict.shape)
    testScore = np.mean(abs((testY_raw[0]-testPredict[:,0])/testY_raw[0]))
    print('Test Score: %.3f MAPE' % (testScore))
        
    # plot baseline and predictions    
    plt.figure(figsize=(20, 10))
    plt.title('Training dataset and Prediction')
    plt.plot(trainY_raw, color='k', label='TRUE')
    plt.plot(trainPredict, color='r', label='PRED')

    plt.show()
    
    
    # plot baseline and predictions    
    plt.figure(figsize=(20, 10))
    plt.title('Test dataset and Prediction')
    plt.plot(testY_raw, color='k', label='TRUE')
    plt.plot(testPredict, color='r', label='PRED')

    plt.show()
# Out:
# (2327, 1) (2327, 1)
# Train Score: 0.234 MAPE
# (118, 1) (118, 1)
# Test Score: 0.466 MAPE

# %%
    if is_train == False:
        model_LSTM.load_weights('model_lstm_multi_best.hd5')

    # lstm预测结果
    
    trainPredict = model_LSTM.predict(trainX)
    testPredict = model_LSTM.predict(testX)
    
    trainPredict = feature_inverse_rescaling(trainPredict,0,train_min,train_max)
    
    testPredict = feature_inverse_rescaling(testPredict,0,test_min,test_max)
    
    trainScore = np.mean(abs((trainY_raw[0]-trainPredict[:,0])/trainY_raw[0]))
    print('Train Score: %.3f MAPE' % (trainScore))
    
    testScore = np.mean(abs((testY_raw[0]-testPredict[:,0])/testY_raw[0]))
    print('Test Score: %.3f MAPE' % (testScore))
    
    # plot baseline and predictions    
    plt.figure(figsize=(20, 10))
    plt.title('Training dataset and Prediction (LSTM)')
    plt.plot(trainY_raw, color='k', label='TRUE')
    plt.plot(trainPredict, color='r', label='PRED')

    plt.show()
    
    # plot baseline and predictions    
    plt.figure(figsize=(20, 10))
    plt.title('Test dataset and Prediction (LSTM)')
    plt.plot(testY_raw, color='k', label='TRUE')
    plt.plot(testPredict, color='r', label='PRED')

    plt.show()
# Out:
# Train Score: 0.186 MAPE
# Test Score: 0.505 MAPE

# %%
    if is_train == False:
        model_LSTM.load_weights('model_lstm_multi_best.hd5')
        model_PLSTM.load_weights('model_plstm_multi_best.hd5')

    # lstm预测结果 (去掉test前部异常数据)
    
    testX, testY = create_dataset(test, seq_len)
    
    testX = np.reshape(testX, (testX.shape[0], seq_len, testX.shape[2]))
    testY = np.reshape(testY, (testY.shape[0], 1))
    
    print(testX.shape, testY.shape)
        
    testPredict_lstm = model_LSTM.predict(testX)
    testPredict_plstm = model_PLSTM.predict(testX)
    
    testPredict_lstm = feature_inverse_rescaling(testPredict_lstm,0,test_min,test_max)
    testPredict_plstm = feature_inverse_rescaling(testPredict_plstm,0,test_min,test_max)    
    testY_raw = feature_inverse_rescaling(testY,0,test_min,test_max)
    
    testScore_lstm = np.mean(abs((testY_raw[0]-testPredict_lstm[:,0])/testY_raw[0]))
    print('Test Score (lstm): %.3f MAPE' % (testScore_lstm))
    
    testScore_plstm = np.mean(abs((testY_raw[0]-testPredict_plstm[:,0])/testY_raw[0]))
    print('Test Score (plstm): %.3f MAPE' % (testScore_plstm))
    
    # plot baseline and predictions    
    plt.figure(figsize=(20, 10))
    plt.title('Test partial dataset and Prediction (LSTM VS PLSTM)')
    plt.plot(testY_raw, color='k', label='TRUE')
    plt.plot(testPredict_lstm, color='r', label='LSTM_PRED')
    plt.plot(testPredict_plstm, color='g', label='PLSTM_PRED')

    plt.show()
# Out:
# (88, 30, 5) (88, 1)
# Test Score (lstm): 0.074 MAPE
# Test Score (plstm): 0.091 MAPE

# %%
    if is_train:
        plt.figure(figsize=(20, 10))
        plt.title('Loss on training dataset')
        plt.xlabel('Iterations, batch size ' + str(batch_size))
        plt.ylabel('mean_squared_error')
        plt.plot(loss_LSTM.losses, color='r', label='LSTM')
        plt.plot(loss_PLSTM.losses, color='g', label='PLSTM')

        plt.show()

# %%
    if False:
        plt.figure(figsize=(20, 10))
        plt.title('Mape on training dataset')
        plt.xlabel('Iterations, batch size ' + str(batch_size))
        plt.ylabel('mape')
        plt.plot(mape_LSTM.losses, color='k', label='LSTM')
        plt.plot(mape_PLSTM.losses, color='r', label='PLSTM')

        plt.show()
